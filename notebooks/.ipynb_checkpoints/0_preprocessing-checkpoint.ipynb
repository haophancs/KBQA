# %%
import os
os.chdir('/mpqa/KBQA/src')
from setup import IndexSearch, Mongo_Connector

e_index = IndexSearch('dbpedia201604e')
p_index = IndexSearch('dbpedia201604p')

import json
from collections import Counter

# %% [markdown]
# ### LC-QUAD

# %%
mongo = Mongo_Connector('kbqa', 'lcquad')
os.chdir("/mpqa/KBQA/data/lcquad")
lcquad_path = "lcquad_answers.json"
mongo.load_json(lcquad_path)
mongo.count_all_docs()
doc = mongo.get_sample(limit=1).next()
doc
# Out:
# Inserting 4998 new docs
# 4998 docs
# {'_id': ObjectId('6113d58560089a940b8a2516'),
#  'sparql_id': '301',
#  'question': 'Which comic characters are painted by Bill Finger?',
#  'SerialNumber': '1',
#  'sparql_query': 'SELECT DISTINCT ?uri WHERE {?uri <http://dbpedia.org/ontology/creator> <http://dbpedia.org/resource/Bill_Finger>  . ?uri <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/ComicsCharacter>}',
#  'checked': 'true',
#  'entity mapping': [{'label': 'Bill Finger',
#    'matchedBy': 'spotlight',
#    'uri': 'http://dbpedia.org/resource/Bill_Finger',
#    'seq': '38,49'}],
#  'id': 'f0a9f1ca14764095ae089b152e0e7f12',
#  'predicate mapping': [{'label': 'painted by',
#    'uri': 'http://dbpedia.org/ontology/creator',
#    'seq': '27,37',
#    'mappedBy': 'manual corrections'},
#   {'label': 'comic characters',
#    'uri': 'http://dbpedia.org/ontology/ComicsCharacter',
#    'seq': '6,22',
#    'mappedBy': 'manual corrections'}],
#  'answers': ['http://dbpedia.org/resource/Batman',
#   'http://dbpedia.org/resource/Alfred_Pennyworth',
#   'http://dbpedia.org/resource/Apache_Chief',
#   'http://dbpedia.org/resource/James_Gordon_(comics)',
#   'http://dbpedia.org/resource/Hugo_Strange',
#   'http://dbpedia.org/resource/Wildcat_(comics)',
#   'http://dbpedia.org/resource/Bat-Mite',
#   'http://dbpedia.org/resource/Vicki_Vale',
#   'http://dbpedia.org/resource/Squire_(comics)',
#   'http://dbpedia.org/resource/Crime_Doctor_(comics)',
#   'http://dbpedia.org/resource/Knight_(comics)',
#   'http://dbpedia.org/resource/Signalman_(comics)',
#   'http://dbpedia.org/resource/Lana_Lang',
#   'http://dbpedia.org/resource/Penguin_(comics)',
#   'http://dbpedia.org/resource/Riddler',
#   'http://dbpedia.org/resource/Scarecrow_(DC_Comics)',
#   'http://dbpedia.org/resource/Dick_Grayson',
#   'http://dbpedia.org/resource/Lori_Lemaris',
#   'http://dbpedia.org/resource/Two-Face',
#   'http://dbpedia.org/resource/Clayface',
#   'http://dbpedia.org/resource/Super-Sons',
#   'http://dbpedia.org/resource/Mad_Hatter_(comics)',
#   'http://dbpedia.org/resource/Firefly_(DC_Comics)',
#   'http://dbpedia.org/resource/Killer_Moth',
#   'http://dbpedia.org/resource/Catman_(comics)',
#   'http://dbpedia.org/resource/Doiby_Dickles',
#   'http://dbpedia.org/resource/Martha_Wayne',
#   'http://dbpedia.org/resource/Ace_the_Bat-Hound',
#   'http://dbpedia.org/resource/Calendar_Man',
#   'http://dbpedia.org/resource/Alan_Scott',
#   'http://dbpedia.org/resource/Tony_Zucco',
#   'http://dbpedia.org/resource/Isbisa',
#   'http://dbpedia.org/resource/Batman_(Dark_Knight_Universe)',
#   'http://dbpedia.org/resource/Tiger_Shark_(DC_Comics)',
#   'http://dbpedia.org/resource/Joker_(comics)',
#   'http://dbpedia.org/resource/Thomas_Wayne',
#   'http://dbpedia.org/resource/Robin_(Earth-Two)',
#   'http://dbpedia.org/resource/Lew_Moxon',
#   'http://dbpedia.org/resource/Batman_(Terry_McGinnis)',
#   'http://dbpedia.org/resource/Joe_Chill',
#   'http://dbpedia.org/resource/Professor_Milo',
#   'http://dbpedia.org/resource/Kite_Man',
#   'http://dbpedia.org/resource/Zebra-Man',
#   'http://dbpedia.org/resource/Bette_Kane',
#   'http://dbpedia.org/resource/Batman_(Earth-Two)',
#   'http://dbpedia.org/resource/Sal_Maroni'],
#  'question_type': 'SELECT'}

# %%
# reproduce the original lcquad test/train splits
limit = None
lcquad_train_path = 'train-data.json'  # wget https://raw.githubusercontent.com/AskNowQA/LC-QuAD/data/train-data.json

X_train = []
   
with open(lcquad_train_path, "r") as json_file:
    docs = json.load(json_file)
    for doc in docs:
        X_train.append(str(int(doc['_id']) + 1))
    print("%d docs loaded"%len(docs))

print("%d train samples" % (len(X_train)))
# annotate
samples = mongo.get_sample(limit=limit)
train_count = 0
for doc in samples:
    if doc['SerialNumber'] in X_train:
        doc['train'] = True
        train_count += 1
    else:
        doc['train'] = False
    mongo.col.update_one({'_id': doc['_id']}, {"$set": doc}, upsert=True)
print("Train: {}, Test: {}".format(train_count, samples.count() - train_count))
sample = mongo.get_sample(limit=1)[100]
print(sample['train'])
# Out:
# 4000 docs loaded
# 4000 train samples
# Train: 3999, Test: 999
# True
# /mpqa/miniconda3/envs/kbqa/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.

# %%
# annotate GS entities and predicates across hops
# parse entities and predicates annotations across hops from the SQL query and update MongoDB collection
verbose = False
limit = None

samples = mongo.get_sample(limit=limit)
count = 0
for doc in samples:
    # fix URI !
    sparql_query = doc['sparql_query']
    # parse the SPARQL query into spo triples
    tripples = sparql_query[sparql_query.find("{")+1:sparql_query.find("}")].split('. ')

    # collect entities and predicates separately for 2 hops
    correct_intermediate_predicates = []
    correct_intermediate_entities = []
    correct_question_predicates = []
    correct_question_entities = []

    for tripple in tripples:
        if tripple:
            entities = []
            s, p, o = tripple.strip().split()
            if s[0] != '?':
                entities.append(s[1:-1])
            if o[0] != '?':
                entities.append(o[1:-1])
            p = p[1:-1]

            if '?uri' not in tripple:
                correct_intermediate_predicates.append(p)
                correct_intermediate_entities.extend(entities)
            else:
                correct_question_predicates.append(p)
                correct_question_entities.extend(entities)
    if verbose:
        print('\n')
        print(sparql_query)
        print(correct_intermediate_entities, correct_intermediate_predicates)
        print(correct_question_entities, correct_question_predicates)

    # update question annotations save in MongoDB
    if not correct_intermediate_predicates:
        # 1 hop
        doc['1hop'] = [correct_question_entities, correct_question_predicates]
        doc['2hop'] = [[], []]
    else:
        # 2 hops
        doc['1hop'] = [correct_intermediate_entities, correct_intermediate_predicates]
        doc['2hop'] = [correct_question_entities, correct_question_predicates]

    doc['entity_uris'] = list(set(correct_question_entities+correct_intermediate_entities))
    # store all predicate URIs for subgraph extraction
    doc['predicate_uris'] = list(set(correct_question_predicates+correct_intermediate_predicates))

    mongo.col.update_one({'_id': doc['_id']}, {"$set": doc}, upsert=True)
    count +=1

print("%d documents annotated with entities and predicates URIs across hops"%count)

# show sample annotation
sample = mongo.get_by_id("3").next()
print(sample['1hop'])
print(sample['2hop'])
print(sample['entity_uris'])
print(sample['predicate_uris'])
# Out:
# 4998 documents annotated with entities and predicates URIs across hops
# [['http://dbpedia.org/resource/Gestapo'], ['http://dbpedia.org/ontology/parentOrganisation']]
# [[], ['http://dbpedia.org/ontology/leader']]
# ['http://dbpedia.org/resource/Gestapo']
# ['http://dbpedia.org/ontology/leader', 'http://dbpedia.org/ontology/parentOrganisation']

# %%
# store HDT IDs across hops
limit = None

def annotate_hop_ids(hop):
    e_found = 0
    e_not_found = 0
    p_found = 0
    p_not_found = 0
    
    samples = mongo.get_all(limit=limit)
    count = 0
    for doc in samples:
        e, p = doc[hop]
        e_ids = []
        for uri in e:
            try:
                e_ids.append(e_index.look_up_by_uri(uri)[0]['_source']['id'])
                e_found += 1
            except IndexError:
                uri = str(uri).encode('utf-8')
                print("{} not found in the entity catalog".format(uri))
                e_not_found += 1

        p_ids = []
        for uri in p:
            try:
                p_ids.append(p_index.look_up_by_uri(uri)[0]['_source']['id'])
                p_found += 1
            except IndexError:
                uri = str(uri).encode('utf-8')
                print("{} not found in the predicate catalog".format(uri))
                p_not_found += 1
        
        doc[hop+'_ids'] = e_ids, p_ids
            
        # update doc in MongoDB
        mongo.col.update_one({'_id': doc['_id']}, {"$set": doc}, upsert=True)
        count += 1
        
    print("%d documents annotated with ids"%count)
    print(e_found, e_not_found, p_found, p_not_found)


annotate_hop_ids('1hop')
annotate_hop_ids('2hop')

# show sample annotations
sample = mongo.get_sample(limit=1)[0]
print(sample['1hop_ids'])
print(sample['2hop_ids'])
# Out:
# b'http://dbpedia.org/resource/Bill_Finger' not found in the entity catalog
# b'http://dbpedia.org/ontology/ComicsCharacter' not found in the entity catalog
# b'http://dbpedia.org/ontology/creator' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Selwyn_Lloyd' not found in the entity catalog
# b'http://dbpedia.org/resource/Winston_Churchill' not found in the entity catalog
# b'http://dbpedia.org/ontology/primeMinister' not found in the predicate catalog
# b'http://dbpedia.org/resource/Gestapo' not found in the entity catalog
# b'http://dbpedia.org/ontology/parentOrganisation' not found in the predicate catalog
# b'http://dbpedia.org/resource/Mumbai_North_(Lok_Sabha_constituency)' not found in the entity catalog
# b'http://dbpedia.org/property/constituency' not found in the predicate catalog
# b'http://dbpedia.org/resource/Roberto_Clemente_Bridge' not found in the entity catalog
# b'http://dbpedia.org/ontology/municipality' not found in the predicate catalog
# b'http://dbpedia.org/resource/Cleopatra_V_of_Egypt' not found in the entity catalog
# b'http://dbpedia.org/resource/Ptolemy_XIII_Theos_Philopator' not found in the entity catalog
# b'http://dbpedia.org/ontology/Royalty' not found in the entity catalog
# b'http://dbpedia.org/property/mother' not found in the predicate catalog
# b'http://dbpedia.org/property/spouse' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Li_Si' not found in the entity catalog
# b'http://dbpedia.org/ontology/successor' not found in the predicate catalog
# b'http://dbpedia.org/resource/Pavel_Moroz' not found in the entity catalog
# b'http://dbpedia.org/resource/Yakov_Estrin' not found in the entity catalog
# b'http://dbpedia.org/property/hometown' not found in the predicate catalog
# b'http://dbpedia.org/ontology/deathPlace' not found in the predicate catalog
# b'http://dbpedia.org/resource/Broadmeadows,_Victoria' not found in the entity catalog
# b'http://dbpedia.org/ontology/Automobile' not found in the entity catalog
# b'http://dbpedia.org/property/assembly' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/ASC_Creative_Services' not found in the entity catalog
# b'http://dbpedia.org/ontology/Automobile' not found in the entity catalog
# b'http://dbpedia.org/ontology/designCompany' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Ernest_Rutherford' not found in the entity catalog
# b'http://dbpedia.org/resource/Charles_Drummond_Ellis' not found in the entity catalog
# b'http://dbpedia.org/ontology/Scientist' not found in the entity catalog
# b'http://dbpedia.org/ontology/doctoralAdvisor' not found in the predicate catalog
# b'http://dbpedia.org/property/doctoralStudents' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/REP_Parasol' not found in the entity catalog
# b'http://dbpedia.org/ontology/designer' not found in the predicate catalog
# b"http://dbpedia.org/resource/Monroe_Carell_Jr._Children's_Hospital_at_Vanderbilt" not found in the entity catalog
# b'http://dbpedia.org/resource/Duncan_U._Fletcher' not found in the entity catalog
# b'http://dbpedia.org/property/affiliation' not found in the predicate catalog
# b'http://dbpedia.org/ontology/almaMater' not found in the predicate catalog
# b'http://dbpedia.org/resource/Josef_Johansson' not found in the entity catalog
# b'http://dbpedia.org/resource/Nader_Guirat' not found in the entity catalog
# b'http://dbpedia.org/property/birthPlace' not found in the predicate catalog
# b'http://dbpedia.org/ontology/hometown' not found in the predicate catalog
# b'http://dbpedia.org/resource/The_Sarah_Jane_Adventures' not found in the entity catalog
# b'http://dbpedia.org/resource/Doctor_Who_Confidential' not found in the entity catalog
# b'http://dbpedia.org/ontology/related' not found in the predicate catalog
# b'http://dbpedia.org/ontology/related' not found in the predicate catalog
# b'http://dbpedia.org/resource/HBO' not found in the entity catalog
# b'http://dbpedia.org/ontology/TelevisionShow' not found in the entity catalog
# b'http://dbpedia.org/ontology/company' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Stanislav_Morozov' not found in the entity catalog
# b'http://dbpedia.org/resource/Nikolai_Morozov_(figure_skater)' not found in the entity catalog
# b'http://dbpedia.org/ontology/formerCoach' not found in the predicate catalog
# b'http://dbpedia.org/resource/Abhijit_Kunte' not found in the entity catalog
# b'http://dbpedia.org/resource/Virtual_Kasparov' not found in the entity catalog
# b'http://dbpedia.org/property/knownFor' not found in the predicate catalog
# b'http://dbpedia.org/ontology/genre' not found in the predicate catalog
# b'http://dbpedia.org/resource/MSX_BASIC' not found in the entity catalog
# b'http://dbpedia.org/resource/Outlook_on_the_web' not found in the entity catalog
# b'http://dbpedia.org/property/license' not found in the predicate catalog
# b'http://dbpedia.org/property/owner' not found in the predicate catalog
# b'http://dbpedia.org/resource/Ronaldo' not found in the entity catalog
# b'http://dbpedia.org/ontology/chairman' not found in the predicate catalog
# b'http://dbpedia.org/resource/Samur\xe2\x80\x93Absheron_channel' not found in the entity catalog
# b'http://dbpedia.org/resource/Anar_Salmanov' not found in the entity catalog
# b'http://dbpedia.org/ontology/sourceCountry' not found in the predicate catalog
# b'http://dbpedia.org/property/placeOfBirth' not found in the predicate catalog
# b'http://dbpedia.org/resource/2nd_Foreign_Infantry_Regiment' not found in the entity catalog
# b'http://dbpedia.org/ontology/MilitaryConflict' not found in the entity catalog
# b'http://dbpedia.org/ontology/battle' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/SR_class_3Sub' not found in the entity catalog
# b'http://dbpedia.org/ontology/operator' not found in the predicate catalog
# b'http://dbpedia.org/resource/Kevin_Jonas' not found in the entity catalog
# b'http://dbpedia.org/resource/Joe_Jonas' not found in the entity catalog
# b'http://dbpedia.org/ontology/Band' not found in the entity catalog
# b'http://dbpedia.org/ontology/formerBandMember' not found in the predicate catalog
# b'http://dbpedia.org/property/pastMembers' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Sunrise_(How_I_Met_Your_Mother)' not found in the entity catalog
# b'http://dbpedia.org/resource/Tim_Gunn' not found in the entity catalog
# b'http://dbpedia.org/property/guests' not found in the predicate catalog
# b'http://dbpedia.org/resource/O.co_Coliseum' not found in the entity catalog
# b'http://dbpedia.org/ontology/tenant' not found in the predicate catalog
# b'http://dbpedia.org/resource/Rishikesh' not found in the entity catalog
# b'http://dbpedia.org/ontology/leaderName' not found in the predicate catalog
# b'http://dbpedia.org/resource/Airtours_International_Airways' not found in the entity catalog
# b'http://dbpedia.org/resource/North_America' not found in the entity catalog
# b'http://dbpedia.org/ontology/destination' not found in the predicate catalog
# b'http://dbpedia.org/resource/National_Medal_of_Science' not found in the entity catalog
# b'http://dbpedia.org/property/prizes' not found in the predicate catalog
# b'http://dbpedia.org/resource/2000\xe2\x80\x9301_Aston_Villa_F.C._season' not found in the entity catalog
# b'http://dbpedia.org/resource/2009\xe2\x80\x9310_Middlesbrough_F.C._season' not found in the entity catalog
# b'http://dbpedia.org/property/name' not found in the predicate catalog
# b'http://dbpedia.org/ontology/manager' not found in the predicate catalog
# b'http://dbpedia.org/resource/William_Harper_(Rhodesian_politician)' not found in the entity catalog
# b'http://dbpedia.org/ontology/militaryBranch' not found in the predicate catalog
# b'http://dbpedia.org/resource/PCL_Construction' not found in the entity catalog
# b'http://dbpedia.org/ontology/builder' not found in the predicate catalog
# b'http://dbpedia.org/resource/Jonas_Brothers' not found in the entity catalog
# b'http://dbpedia.org/resource/Kevin_Jonas' not found in the entity catalog
# b'http://dbpedia.org/ontology/formerBandMember' not found in the predicate catalog
# b'http://dbpedia.org/resource/Cosmos_(Carl_Sagan_book)' not found in the entity catalog
# b'http://dbpedia.org/ontology/Book' not found in the entity catalog
# b'http://dbpedia.org/ontology/subsequentWork' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Rosemont,_Illinois' not found in the entity catalog
# b'http://dbpedia.org/ontology/Convention' not found in the entity catalog
# b'http://dbpedia.org/ontology/location' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Greenup_County_High_School' not found in the entity catalog
# b'http://dbpedia.org/property/type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Bobby_Hoppe' not found in the entity catalog
# b'http://dbpedia.org/property/pastteams' not found in the predicate catalog
# b'http://dbpedia.org/resource/The_Second_Coming_(TV_serial)' not found in the entity catalog
# b'http://dbpedia.org/property/writer' not found in the predicate catalog
# b'http://dbpedia.org/resource/Miguel_de_Cervantes' not found in the entity catalog
# b'http://dbpedia.org/ontology/Book' not found in the entity catalog
# b'http://dbpedia.org/ontology/author' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Progressive_rock' not found in the entity catalog
# b'http://dbpedia.org/ontology/MusicalArtist' not found in the entity catalog
# b'http://dbpedia.org/property/genre' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Reading,_Berkshire' not found in the entity catalog
# b'http://dbpedia.org/ontology/city' not found in the predicate catalog
# b'http://dbpedia.org/resource/Crystal_Harris' not found in the entity catalog
# b'http://dbpedia.org/property/spouse' not found in the predicate catalog
# b'http://dbpedia.org/resource/West_Thurrock' not found in the entity catalog
# b'http://dbpedia.org/resource/Essex' not found in the entity catalog
# b'http://dbpedia.org/ontology/ceremonialCounty' not found in the predicate catalog
# b'http://dbpedia.org/resource/Niederkirchnerstra\xc3\x9fe' not found in the entity catalog
# b'http://dbpedia.org/ontology/headquarter' not found in the predicate catalog
# b'http://dbpedia.org/resource/Steven_Moffat' not found in the entity catalog
# b'http://dbpedia.org/ontology/TelevisionShow' not found in the entity catalog
# b'http://dbpedia.org/ontology/executiveProducer' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Ford_Falcon_Cobra' not found in the entity catalog
# b'http://dbpedia.org/resource/Dagenham_wind_turbines' not found in the entity catalog
# b'http://dbpedia.org/ontology/parentCompany' not found in the predicate catalog
# b'http://dbpedia.org/property/owner' not found in the predicate catalog
# b'http://dbpedia.org/resource/San_Francisco_International_Airport' not found in the entity catalog
# b'http://dbpedia.org/ontology/Airline' not found in the entity catalog
# b'http://dbpedia.org/property/hubs' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Maritime_Museum_of_San_Diego' not found in the entity catalog
# b'http://dbpedia.org/property/governingBody' not found in the predicate catalog
# b'http://dbpedia.org/resource/Trinity_School,_Brentwood' not found in the entity catalog
# b'http://dbpedia.org/resource/Sarah_Walker_(badminton)' not found in the entity catalog
# b'http://dbpedia.org/ontology/localAuthority' not found in the predicate catalog
# b'http://dbpedia.org/property/placeOfBirth' not found in the predicate catalog
# b'http://dbpedia.org/resource/21Vianet' not found in the entity catalog
# b'http://dbpedia.org/property/services' not found in the predicate catalog
# b'http://dbpedia.org/resource/Johann_Gottfried_Galle' not found in the entity catalog
# b'http://dbpedia.org/resource/Urbain_Le_Verrier' not found in the entity catalog
# b'http://dbpedia.org/ontology/Planet' not found in the entity catalog
# b'http://dbpedia.org/property/discoverer' not found in the predicate catalog
# b'http://dbpedia.org/ontology/discoverer' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Elmer_Burkett' not found in the entity catalog
# b'http://dbpedia.org/ontology/OfficeHolder' not found in the entity catalog
# b'http://dbpedia.org/property/successor' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Steve_Ontiveros_(infielder)' not found in the entity catalog
# b'http://dbpedia.org/resource/Hensley_Meulens' not found in the entity catalog
# b'http://dbpedia.org/property/debutteam' not found in the predicate catalog
# b'http://dbpedia.org/ontology/team' not found in the predicate catalog
# b'http://dbpedia.org/resource/Lucy_Sullivan_Is_Getting_Married' not found in the entity catalog
# b'http://dbpedia.org/property/starring' not found in the predicate catalog
# b'http://dbpedia.org/resource/Faaa' not found in the entity catalog
# b'http://dbpedia.org/resource/Society_Islands' not found in the entity catalog
# b'http://dbpedia.org/ontology/Island' not found in the entity catalog
# b'http://dbpedia.org/ontology/largestCity' not found in the predicate catalog
# b'http://dbpedia.org/property/archipelago' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/1997_Canadian_Grand_Prix' not found in the entity catalog
# b'http://dbpedia.org/resource/1994_Spanish_Grand_Prix' not found in the entity catalog
# b'http://dbpedia.org/property/poleDriver' not found in the predicate catalog
# b'http://dbpedia.org/property/poleDriver' not found in the predicate catalog
# b'http://dbpedia.org/resource/Richard_Winn' not found in the entity catalog
# b'http://dbpedia.org/ontology/governor' not found in the predicate catalog
# b'http://dbpedia.org/resource/Arthur_D._Levinson' not found in the entity catalog
# b'http://dbpedia.org/resource/Sherlock_(software)' not found in the entity catalog
# b'http://dbpedia.org/ontology/occupation' not found in the predicate catalog
# b'http://dbpedia.org/ontology/developer' not found in the predicate catalog
# b'http://dbpedia.org/resource/MasterCard_Centre' not found in the entity catalog
# b'http://dbpedia.org/resource/Sam_Carrick' not found in the entity catalog
# b'http://dbpedia.org/property/tenants' not found in the predicate catalog
# b'http://dbpedia.org/property/draftTeam' not found in the predicate catalog
# b'http://dbpedia.org/resource/FremantleMedia' not found in the entity catalog
# b'http://dbpedia.org/ontology/TelevisionShow' not found in the entity catalog
# b'http://dbpedia.org/property/company' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/South_Loop_Printing_House_District' not found in the entity catalog
# b'http://dbpedia.org/ontology/architecturalStyle' not found in the predicate catalog
# b'http://dbpedia.org/resource/Outlook.com' not found in the entity catalog
# b'http://dbpedia.org/resource/Microsoft_Visual_Studio' not found in the entity catalog
# b'http://dbpedia.org/property/services' not found in the predicate catalog
# b'http://dbpedia.org/property/products' not found in the predicate catalog
# b'http://dbpedia.org/resource/Ombla' not found in the entity catalog
# b'http://dbpedia.org/resource/Croatia' not found in the entity catalog
# b'http://dbpedia.org/ontology/sourceMountain' not found in the predicate catalog
# b'http://dbpedia.org/resource/Newin_Chidchob' not found in the entity catalog
# b'http://dbpedia.org/property/nationality' not found in the predicate catalog
# b'http://dbpedia.org/resource/Dave_Bing' not found in the entity catalog
# b'http://dbpedia.org/resource/Ron_Reed' not found in the entity catalog
# b'http://dbpedia.org/property/draftTeam' not found in the predicate catalog
# b'http://dbpedia.org/property/draftTeam' not found in the predicate catalog
# b'http://dbpedia.org/resource/Ganymede_(moon)' not found in the entity catalog
# b'http://dbpedia.org/resource/Galileo_Galilei' not found in the entity catalog
# b'http://dbpedia.org/property/discoverer' not found in the predicate catalog
# b'http://dbpedia.org/resource/Guitar' not found in the entity catalog
# b'http://dbpedia.org/property/notableInstruments' not found in the predicate catalog
# b'http://dbpedia.org/resource/Elizabeth:_The_Golden_Age_(soundtrack)' not found in the entity catalog
# b'http://dbpedia.org/property/producer' not found in the predicate catalog
# b'http://dbpedia.org/resource/OneDrive' not found in the entity catalog
# b'http://dbpedia.org/ontology/Company' not found in the entity catalog
# b'http://dbpedia.org/property/services' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Washington,_D.C.' not found in the entity catalog
# b'http://dbpedia.org/ontology/foundationPlace' not found in the predicate catalog
# b'http://dbpedia.org/resource/Queen_Noor_of_Jordan' not found in the entity catalog
# b'http://dbpedia.org/ontology/School' not found in the entity catalog
# b'http://dbpedia.org/ontology/president' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Robert_Witherspoon' not found in the entity catalog
# b'http://dbpedia.org/ontology/governor' not found in the predicate catalog
# b"http://dbpedia.org/resource/He's_a_Liar" not found in the entity catalog
# b'http://dbpedia.org/ontology/Song' not found in the entity catalog
# b'http://dbpedia.org/ontology/previousWork' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Oj,_svijetla_majska_zoro' not found in the entity catalog
# b'http://dbpedia.org/ontology/anthem' not found in the predicate catalog
# b'http://dbpedia.org/resource/Allen_Walker' not found in the entity catalog
# b'http://dbpedia.org/ontology/voice' not found in the predicate catalog
# b'http://dbpedia.org/resource/Publius_Servilius_Vatia_Isauricus_(consul_48_BC)' not found in the entity catalog
# b'http://dbpedia.org/resource/Marcus_Calpurnius_Bibulus' not found in the entity catalog
# b'http://dbpedia.org/ontology/associate' not found in the predicate catalog
# b'http://dbpedia.org/ontology/associate' not found in the predicate catalog
# b'http://dbpedia.org/resource/Saima_Chowdhury' not found in the entity catalog
# b'http://dbpedia.org/resource/Edmund_John' not found in the entity catalog
# b'http://dbpedia.org/ontology/citizenship' not found in the predicate catalog
# b'http://dbpedia.org/ontology/citizenship' not found in the predicate catalog
# b'http://dbpedia.org/resource/Cathedral_Peak_(California)' not found in the entity catalog
# b'http://dbpedia.org/resource/Mount_Hoffmann' not found in the entity catalog
# b'http://dbpedia.org/ontology/firstAscentPerson' not found in the predicate catalog
# b'http://dbpedia.org/ontology/firstAscentPerson' not found in the predicate catalog
# b'http://dbpedia.org/resource/Indiana' not found in the entity catalog
# b'http://dbpedia.org/ontology/University' not found in the entity catalog
# b'http://dbpedia.org/ontology/campus' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Swedish_Covenant_Hospital' not found in the entity catalog
# b'http://dbpedia.org/ontology/location' not found in the predicate catalog
# b'http://dbpedia.org/resource/Girl_from_the_North_Country' not found in the entity catalog
# b'http://dbpedia.org/resource/Moondog_Matinee' not found in the entity catalog
# b'http://dbpedia.org/ontology/composer' not found in the predicate catalog
# b'http://dbpedia.org/ontology/subsequentWork' not found in the predicate catalog
# b'http://dbpedia.org/resource/April_Stewart' not found in the entity catalog
# b'http://dbpedia.org/resource/Mona_Marshall' not found in the entity catalog
# b'http://dbpedia.org/ontology/TelevisionShow' not found in the entity catalog
# b'http://dbpedia.org/property/voices' not found in the predicate catalog
# b'http://dbpedia.org/property/voices' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Freedom_of_the_City' not found in the entity catalog
# b'http://dbpedia.org/resource/Trinity_House' not found in the entity catalog
# b'http://dbpedia.org/ontology/board' not found in the predicate catalog
# b'http://dbpedia.org/ontology/board' not found in the predicate catalog
# b'http://dbpedia.org/resource/Reza_Amrollahi' not found in the entity catalog
# b'http://dbpedia.org/resource/Iran' not found in the entity catalog
# b'http://dbpedia.org/property/birthplace' not found in the predicate catalog
# b'http://dbpedia.org/resource/Zaman_Shah_Durrani' not found in the entity catalog
# b'http://dbpedia.org/resource/Salahuddin_Rabbani' not found in the entity catalog
# b'http://dbpedia.org/property/title' not found in the predicate catalog
# b'http://dbpedia.org/ontology/nationality' not found in the predicate catalog
# b'http://dbpedia.org/resource/Roh_Tae-woo' not found in the entity catalog
# b'http://dbpedia.org/resource/Lee_Leffingwell' not found in the entity catalog
# b'http://dbpedia.org/ontology/battle' not found in the predicate catalog
# b'http://dbpedia.org/ontology/battle' not found in the predicate catalog
# b'http://dbpedia.org/resource/Rosemarie_DeWitt' not found in the entity catalog
# b'http://dbpedia.org/ontology/Film' not found in the entity catalog
# b'http://dbpedia.org/property/starring' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Sapindales' not found in the entity catalog
# b'http://dbpedia.org/ontology/order' not found in the predicate catalog
# b'http://dbpedia.org/resource/Lewis_Hamilton' not found in the entity catalog
# b'http://dbpedia.org/ontology/associatedBand' not found in the predicate catalog
# b'http://dbpedia.org/resource/Giorgos_Kaminis' not found in the entity catalog
# b'http://dbpedia.org/ontology/AdministrativeRegion' not found in the entity catalog
# b'http://dbpedia.org/property/mayor' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Michael_Hahn' not found in the entity catalog
# b'http://dbpedia.org/ontology/almaMater' not found in the predicate catalog
# b'http://dbpedia.org/resource/Berlin' not found in the entity catalog
# b'http://dbpedia.org/ontology/headquarter' not found in the predicate catalog
# b'http://dbpedia.org/resource/India' not found in the entity catalog
# b'http://dbpedia.org/ontology/hometown' not found in the predicate catalog
# b'http://dbpedia.org/resource/The_Simpsons_Ride' not found in the entity catalog
# b'http://dbpedia.org/property/starring' not found in the predicate catalog
# b'http://dbpedia.org/resource/O.co_Coliseum' not found in the entity catalog
# b'http://dbpedia.org/ontology/AmericanFootballTeam' not found in the entity catalog
# b'http://dbpedia.org/ontology/locationCity' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/The_Mating_Habits_of_the_Earthbound_Human' not found in the entity catalog
# b'http://dbpedia.org/resource/Mams_Taylor' not found in the entity catalog
# b'http://dbpedia.org/property/starring' not found in the predicate catalog
# b'http://dbpedia.org/ontology/associatedMusicalArtist' not found in the predicate catalog
# b'http://dbpedia.org/resource/Playboy_Enterprises' not found in the entity catalog
# b'http://dbpedia.org/property/products' not found in the predicate catalog
# b'http://dbpedia.org/resource/Gwo_ka' not found in the entity catalog
# b'http://dbpedia.org/resource/West_Africa' not found in the entity catalog
# b'http://dbpedia.org/property/stylisticOrigins' not found in the predicate catalog
# b"http://dbpedia.org/resource/Send_It_On_(Disney's_Friends_for_Change_song)" not found in the entity catalog
# b'http://dbpedia.org/ontology/TelevisionShow' not found in the entity catalog
# b'http://dbpedia.org/ontology/openingTheme' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/OneDrive' not found in the entity catalog
# b'http://dbpedia.org/resource/Microsoft_Visual_Studio' not found in the entity catalog
# b'http://dbpedia.org/ontology/Company' not found in the entity catalog
# b'http://dbpedia.org/property/services' not found in the predicate catalog
# b'http://dbpedia.org/property/products' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Roundhead_(Wyandot)' not found in the entity catalog
# b'http://dbpedia.org/property/commander' not found in the predicate catalog
# b'http://dbpedia.org/resource/Michigan_Stadium' not found in the entity catalog
# b'http://dbpedia.org/property/stadium' not found in the predicate catalog
# b'http://dbpedia.org/resource/David_Johnston' not found in the entity catalog
# b'http://dbpedia.org/ontology/Country' not found in the entity catalog
# b'http://dbpedia.org/ontology/leader' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Fran\xc3\xa7ois-Marie_Le_Marchand_de_Lignery' not found in the entity catalog
# b'http://dbpedia.org/ontology/MilitaryConflict' not found in the entity catalog
# b'http://dbpedia.org/ontology/battle' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Myntdu_River' not found in the entity catalog
# b'http://dbpedia.org/ontology/Town' not found in the entity catalog
# b'http://dbpedia.org/ontology/origin' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/London' not found in the entity catalog
# b'http://dbpedia.org/property/placeOfBirth' not found in the predicate catalog
# b'http://dbpedia.org/resource/Al_Gore_presidential_campaign,_2000' not found in the entity catalog
# b'http://dbpedia.org/resource/Ann_Lewis' not found in the entity catalog
# b'http://dbpedia.org/ontology/incumbent' not found in the predicate catalog
# b'http://dbpedia.org/ontology/president' not found in the predicate catalog
# b'http://dbpedia.org/resource/Darius_I' not found in the entity catalog
# b'http://dbpedia.org/property/predecessor' not found in the predicate catalog
# b'http://dbpedia.org/resource/Kim_Sawchuk' not found in the entity catalog
# b'http://dbpedia.org/resource/Airtours_International_Airways' not found in the entity catalog
# b'http://dbpedia.org/property/region' not found in the predicate catalog
# b'http://dbpedia.org/property/destinations' not found in the predicate catalog
# b'http://dbpedia.org/resource/Antonio_Giannini' not found in the entity catalog
# b'http://dbpedia.org/ontology/birthPlace' not found in the predicate catalog
# b'http://dbpedia.org/resource/David_Scherman' not found in the entity catalog
# b'http://dbpedia.org/ontology/training' not found in the predicate catalog
# b'http://dbpedia.org/resource/Outlook.com' not found in the entity catalog
# b'http://dbpedia.org/resource/OneDrive' not found in the entity catalog
# b'http://dbpedia.org/ontology/Company' not found in the entity catalog
# b'http://dbpedia.org/property/services' not found in the predicate catalog
# b'http://dbpedia.org/property/services' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Rouen_Business_School' not found in the entity catalog
# b'http://dbpedia.org/property/province' not found in the predicate catalog
# b'http://dbpedia.org/resource/Minjoo_Party_of_Korea' not found in the entity catalog
# b'http://dbpedia.org/ontology/OfficeHolder' not found in the entity catalog
# b'http://dbpedia.org/ontology/party' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/McDonnell_Aircraft' not found in the entity catalog
# b'http://dbpedia.org/ontology/employer' not found in the predicate catalog
# b'http://dbpedia.org/resource/Gales_Ferry,_Connecticut' not found in the entity catalog
# b'http://dbpedia.org/ontology/Politician' not found in the entity catalog
# b'http://dbpedia.org/ontology/residence' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Live_in_Detroit,_MI' not found in the entity catalog
# b'http://dbpedia.org/ontology/recordedIn' not found in the predicate catalog
# b'http://dbpedia.org/resource/England_national_under-21_football_team' not found in the entity catalog
# b'http://dbpedia.org/property/managerclubs' not found in the predicate catalog
# b'http://dbpedia.org/resource/Helsinki' not found in the entity catalog
# b'http://dbpedia.org/resource/Danish_straits' not found in the entity catalog
# b'http://dbpedia.org/ontology/Sea' not found in the entity catalog
# b'http://dbpedia.org/property/cities' not found in the predicate catalog
# b'http://dbpedia.org/property/outflow' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Timmy_Time' not found in the entity catalog
# b'http://dbpedia.org/ontology/executiveProducer' not found in the predicate catalog
# b'http://dbpedia.org/resource/Fort_Heath_radar_station' not found in the entity catalog
# b'http://dbpedia.org/property/district' not found in the predicate catalog
# b'http://dbpedia.org/resource/Harding_Academy_(Memphis)' not found in the entity catalog
# b'http://dbpedia.org/resource/Lyons_Township_High_School' not found in the entity catalog
# b'http://dbpedia.org/property/nickname' not found in the predicate catalog
# b'http://dbpedia.org/property/nickname' not found in the predicate catalog
# b'http://dbpedia.org/resource/Rosario,_Santa_Fe' not found in the entity catalog
# b'http://dbpedia.org/property/ground' not found in the predicate catalog
# b'http://dbpedia.org/resource/Animal' not found in the entity catalog
# b'http://dbpedia.org/ontology/Mammal' not found in the entity catalog
# b'http://dbpedia.org/ontology/kingdom' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Chris_Myers_(New_Jersey)' not found in the entity catalog
# b'http://dbpedia.org/resource/Oahu_Railway_and_Land_Company' not found in the entity catalog
# b'http://dbpedia.org/ontology/profession' not found in the predicate catalog
# b'http://dbpedia.org/property/governingBody' not found in the predicate catalog
# b'http://dbpedia.org/resource/Non-governmental_organization' not found in the entity catalog
# b'http://dbpedia.org/property/type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Brian_Graden' not found in the entity catalog
# b'http://dbpedia.org/resource/Isaac_Hayes' not found in the entity catalog
# b'http://dbpedia.org/ontology/TelevisionShow' not found in the entity catalog
# b'http://dbpedia.org/property/developer' not found in the predicate catalog
# b'http://dbpedia.org/property/voices' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Motor_vehicle' not found in the entity catalog
# b'http://dbpedia.org/property/carries' not found in the predicate catalog
# b'http://dbpedia.org/resource/Steve_Sampson' not found in the entity catalog
# b'http://dbpedia.org/resource/Santa_Clara_University' not found in the entity catalog
# b'http://dbpedia.org/ontology/managerClub' not found in the predicate catalog
# b'http://dbpedia.org/resource/Schibsted' not found in the entity catalog
# b'http://dbpedia.org/ontology/Newspaper' not found in the entity catalog
# b'http://dbpedia.org/property/owners' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/WPC_Dynamo_Moscow' not found in the entity catalog
# b'http://dbpedia.org/resource/Tigran_Petrosian' not found in the entity catalog
# b'http://dbpedia.org/property/arena' not found in the predicate catalog
# b'http://dbpedia.org/ontology/deathPlace' not found in the predicate catalog
# b'http://dbpedia.org/resource/Joan_Laporta' not found in the entity catalog
# b'http://dbpedia.org/ontology/SoccerClub' not found in the entity catalog
# b'http://dbpedia.org/ontology/chairman' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Front-engine,_four-wheel-drive_layout' not found in the entity catalog
# b'http://dbpedia.org/ontology/Automobile' not found in the entity catalog
# b'http://dbpedia.org/ontology/layout' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Pong_Pha' not found in the entity catalog
# b'http://dbpedia.org/ontology/timeZone' not found in the predicate catalog
# b'http://dbpedia.org/resource/Angela_Trusty' not found in the entity catalog
# b'http://dbpedia.org/resource/Charles_Ayres' not found in the entity catalog
# b'http://dbpedia.org/ontology/almaMater' not found in the predicate catalog
# b'http://dbpedia.org/ontology/almaMater' not found in the predicate catalog
# b'http://dbpedia.org/resource/The_Conglomerate_(American_group)' not found in the entity catalog
# b'http://dbpedia.org/resource/Before_I_Let_You_Go' not found in the entity catalog
# b'http://dbpedia.org/property/pastMembers' not found in the predicate catalog
# b'http://dbpedia.org/ontology/musicalArtist' not found in the predicate catalog
# b'http://dbpedia.org/resource/Lagnacha_Dhumdhadaka' not found in the entity catalog
# b'http://dbpedia.org/property/starring' not found in the predicate catalog
# b'http://dbpedia.org/resource/English_language' not found in the entity catalog
# b'http://dbpedia.org/ontology/officialLanguage' not found in the predicate catalog
# b'http://dbpedia.org/resource/El_Sobrante,_California' not found in the entity catalog
# b'http://dbpedia.org/ontology/hometown' not found in the predicate catalog
# b"http://dbpedia.org/resource/Daniel_O'Regan" not found in the entity catalog
# b'http://dbpedia.org/property/nickname' not found in the predicate catalog
# b'http://dbpedia.org/resource/Aureus' not found in the entity catalog
# b'http://dbpedia.org/resource/Solidus_(coin)' not found in the entity catalog
# b'http://dbpedia.org/ontology/currency' not found in the predicate catalog
# b'http://dbpedia.org/ontology/currency' not found in the predicate catalog
# b'http://dbpedia.org/resource/Cardiovascular_disease' not found in the entity catalog
# b'http://dbpedia.org/ontology/deathCause' not found in the predicate catalog
# b'http://dbpedia.org/resource/Chestnut_white-bellied_rat' not found in the entity catalog
# b'http://dbpedia.org/resource/Mammal' not found in the entity catalog
# b'http://dbpedia.org/ontology/class' not found in the predicate catalog
# b'http://dbpedia.org/resource/The_Broken_Code' not found in the entity catalog
# b'http://dbpedia.org/resource/Tim_Gunn' not found in the entity catalog
# b'http://dbpedia.org/property/guests' not found in the predicate catalog
# b'http://dbpedia.org/resource/Shallot' not found in the entity catalog
# b'http://dbpedia.org/ontology/ingredient' not found in the predicate catalog
# b'http://dbpedia.org/resource/Oktoc,_Mississippi' not found in the entity catalog
# b'http://dbpedia.org/ontology/AmericanFootballPlayer' not found in the entity catalog
# b'http://dbpedia.org/property/highSchool' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Nord_(video_game)' not found in the entity catalog
# b'http://dbpedia.org/resource/The_Beauty_Inside' not found in the entity catalog
# b'http://dbpedia.org/ontology/computingPlatform' not found in the predicate catalog
# b'http://dbpedia.org/ontology/distributor' not found in the predicate catalog
# b'http://dbpedia.org/resource/Albania' not found in the entity catalog
# b'http://dbpedia.org/resource/Tirana' not found in the entity catalog
# b'http://dbpedia.org/property/largestCity' not found in the predicate catalog
# b'http://dbpedia.org/resource/Fr._Agnel_Multipurpose_School_and_Junior_College' not found in the entity catalog
# b'http://dbpedia.org/resource/Vishwajyot_High_School' not found in the entity catalog
# b'http://dbpedia.org/ontology/sport' not found in the predicate catalog
# b'http://dbpedia.org/ontology/sport' not found in the predicate catalog
# b'http://dbpedia.org/resource/Bob_Hawke' not found in the entity catalog
# b'http://dbpedia.org/ontology/primeMinister' not found in the predicate catalog
# b'http://dbpedia.org/resource/CBS_Corporation' not found in the entity catalog
# b'http://dbpedia.org/ontology/owner' not found in the predicate catalog
# b'http://dbpedia.org/resource/Taguig' not found in the entity catalog
# b'http://dbpedia.org/ontology/EducationalInstitution' not found in the entity catalog
# b'http://dbpedia.org/ontology/city' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Joe_Hahn' not found in the entity catalog
# b'http://dbpedia.org/ontology/Band' not found in the entity catalog
# b'http://dbpedia.org/property/currentMembers' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Comedy_Central' not found in the entity catalog
# b'http://dbpedia.org/resource/Isaac_Hayes' not found in the entity catalog
# b'http://dbpedia.org/ontology/TelevisionShow' not found in the entity catalog
# b'http://dbpedia.org/property/distributor' not found in the predicate catalog
# b'http://dbpedia.org/property/voices' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Raymond_Johansen' not found in the entity catalog
# b'http://dbpedia.org/ontology/leaderName' not found in the predicate catalog
# b'http://dbpedia.org/resource/Ikaros_Smederna' not found in the entity catalog
# b'http://dbpedia.org/ontology/SpeedwayLeague' not found in the entity catalog
# b'http://dbpedia.org/ontology/league' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Microsoft_Windows' not found in the entity catalog
# b'http://dbpedia.org/ontology/VideoGame' not found in the entity catalog
# b'http://dbpedia.org/ontology/computingPlatform' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Hockey' not found in the entity catalog
# b'http://dbpedia.org/ontology/sport' not found in the predicate catalog
# b'http://dbpedia.org/resource/Union_Station_(Washington,_D.C.)' not found in the entity catalog
# b'http://dbpedia.org/ontology/RailwayLine' not found in the entity catalog
# b'http://dbpedia.org/ontology/routeEnd' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Temenos_Group' not found in the entity catalog
# b'http://dbpedia.org/property/foundation' not found in the predicate catalog
# b'http://dbpedia.org/resource/To_Know_Him_Is_to_Love_Him' not found in the entity catalog
# b'http://dbpedia.org/ontology/previousWork' not found in the predicate catalog
# b'http://dbpedia.org/resource/Spain..._on_the_Road_Again' not found in the entity catalog
# b'http://dbpedia.org/ontology/narrator' not found in the predicate catalog
# b'http://dbpedia.org/resource/Chris_Marve' not found in the entity catalog
# b'http://dbpedia.org/resource/Neria_Douglass' not found in the entity catalog
# b'http://dbpedia.org/ontology/school' not found in the predicate catalog
# b'http://dbpedia.org/ontology/almaMater' not found in the predicate catalog
# b'http://dbpedia.org/resource/Monticello,_Maine' not found in the entity catalog
# b'http://dbpedia.org/ontology/RadioStation' not found in the entity catalog
# b'http://dbpedia.org/property/city' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/John_of_Damascus' not found in the entity catalog
# b'http://dbpedia.org/resource/Josiah_Idowu-Fearon' not found in the entity catalog
# b'http://dbpedia.org/ontology/canonizedBy' not found in the predicate catalog
# b'http://dbpedia.org/ontology/religion' not found in the predicate catalog
# b'http://dbpedia.org/resource/Judy_Hart_Angelo' not found in the entity catalog
# b'http://dbpedia.org/resource/Paramount_Television' not found in the entity catalog
# b'http://dbpedia.org/ontology/TelevisionShow' not found in the entity catalog
# b'http://dbpedia.org/ontology/composer' not found in the predicate catalog
# b'http://dbpedia.org/property/company' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Caspian_Sea' not found in the entity catalog
# b'http://dbpedia.org/ontology/River' not found in the entity catalog
# b'http://dbpedia.org/ontology/riverMouth' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Arlington_County,_Virginia' not found in the entity catalog
# b'http://dbpedia.org/resource/United_States_Department_of_Defense' not found in the entity catalog
# b'http://dbpedia.org/ontology/MilitaryUnit' not found in the entity catalog
# b'http://dbpedia.org/ontology/garrison' not found in the predicate catalog
# b'http://dbpedia.org/ontology/commandStructure' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Thongsuk_Samdaengpan' not found in the entity catalog
# b'http://dbpedia.org/property/successor' not found in the predicate catalog
# b'http://dbpedia.org/resource/Asus' not found in the entity catalog
# b'http://dbpedia.org/ontology/InformationAppliance' not found in the entity catalog
# b'http://dbpedia.org/ontology/manufacturer' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/National_Collegiate_Athletic_Association' not found in the entity catalog
# b'http://dbpedia.org/ontology/athletics' not found in the predicate catalog
# b'http://dbpedia.org/resource/Afrika_Baby_Bam' not found in the entity catalog
# b'http://dbpedia.org/resource/Queen_Latifah' not found in the entity catalog
# b'http://dbpedia.org/ontology/associatedBand' not found in the predicate catalog
# b'http://dbpedia.org/resource/Kazuo_Hirai' not found in the entity catalog
# b'http://dbpedia.org/property/keyPeople' not found in the predicate catalog
# b'http://dbpedia.org/resource/PATTS_College_of_Aeronautics' not found in the entity catalog
# b'http://dbpedia.org/property/athletics' not found in the predicate catalog
# b'http://dbpedia.org/resource/Dan_Shamash' not found in the entity catalog
# b'http://dbpedia.org/resource/EverBank_Field' not found in the entity catalog
# b'http://dbpedia.org/ontology/team' not found in the predicate catalog
# b'http://dbpedia.org/ontology/tenant' not found in the predicate catalog
# b'http://dbpedia.org/resource/Thanong_Bidaya' not found in the entity catalog
# b'http://dbpedia.org/property/primeminister' not found in the predicate catalog
# b'http://dbpedia.org/resource/San_Marcos_River' not found in the entity catalog
# b'http://dbpedia.org/ontology/Country' not found in the entity catalog
# b'http://dbpedia.org/ontology/sourceMountain' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Jazz_fusion' not found in the entity catalog
# b'http://dbpedia.org/ontology/MusicalArtist' not found in the entity catalog
# b'http://dbpedia.org/ontology/genre' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Bogumilus' not found in the entity catalog
# b'http://dbpedia.org/ontology/majorShrine' not found in the predicate catalog
# b'http://dbpedia.org/resource/Henry_E._Catto,_Jr.' not found in the entity catalog
# b'http://dbpedia.org/resource/Screen_Actors_Guild_Life_Achievement_Award' not found in the entity catalog
# b'http://dbpedia.org/ontology/OfficeHolder' not found in the entity catalog
# b'http://dbpedia.org/ontology/predecessor' not found in the predicate catalog
# b'http://dbpedia.org/ontology/award' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Pope_Gregory_I' not found in the entity catalog
# b'http://dbpedia.org/property/veneratedIn' not found in the predicate catalog
# b'http://dbpedia.org/resource/Human_Rights_Party_(Cambodia)' not found in the entity catalog
# b'http://dbpedia.org/ontology/Person' not found in the entity catalog
# b'http://dbpedia.org/ontology/otherParty' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/Czech_Extraliga' not found in the entity catalog
# b'http://dbpedia.org/property/league' not found in the predicate catalog
# b'http://dbpedia.org/resource/Croix_de_guerre_1939\xe2\x80\x931945_(France)' not found in the entity catalog
# b'http://dbpedia.org/property/awards' not found in the predicate catalog
# b'http://dbpedia.org/resource/Azam_F.C.' not found in the entity catalog
# b'http://dbpedia.org/ontology/SoccerPlayer' not found in the entity catalog
# b'http://dbpedia.org/property/name' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/resource/INKAS' not found in the entity catalog
# b'http://dbpedia.org/resource/T.I._Ahmadiyya_Senior_High_School,_Kumasi' not found in the entity catalog
# b'http://dbpedia.org/property/locations' not found in the predicate catalog
# b'http://dbpedia.org/ontology/denomination' not found in the predicate catalog
# ...
# b'http://dbpedia.org/ontology/award' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Species' not found in the entity catalog
# b'http://dbpedia.org/ontology/species' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/property/subject' not found in the predicate catalog
# b'http://dbpedia.org/property/artist' not found in the predicate catalog
# b'http://dbpedia.org/property/birthDate' not found in the predicate catalog
# b'http://dbpedia.org/ontology/nationality' not found in the predicate catalog
# b'http://dbpedia.org/property/president' not found in the predicate catalog
# b'http://dbpedia.org/ontology/birthPlace' not found in the predicate catalog
# b'http://dbpedia.org/ontology/tenant' not found in the predicate catalog
# b'http://dbpedia.org/ontology/mountainRange' not found in the predicate catalog
# b'http://dbpedia.org/ontology/religion' not found in the predicate catalog
# b'http://dbpedia.org/ontology/formerTeam' not found in the predicate catalog
# b'http://dbpedia.org/ontology/AmericanFootballPlayer' not found in the entity catalog
# b'http://dbpedia.org/ontology/formerTeam' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/City' not found in the entity catalog
# b'http://dbpedia.org/property/cities' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/territory' not found in the predicate catalog
# b'http://dbpedia.org/ontology/currency' not found in the predicate catalog
# b'http://dbpedia.org/property/judges' not found in the predicate catalog
# b'http://dbpedia.org/ontology/deathPlace' not found in the predicate catalog
# b'http://dbpedia.org/property/awards' not found in the predicate catalog
# b'http://dbpedia.org/property/judges' not found in the predicate catalog
# b'http://dbpedia.org/property/area' not found in the predicate catalog
# b'http://dbpedia.org/ontology/ethnicity' not found in the predicate catalog
# b'http://dbpedia.org/ontology/award' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Person' not found in the entity catalog
# b'http://dbpedia.org/ontology/trainer' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/TelevisionShow' not found in the entity catalog
# b'http://dbpedia.org/property/company' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/property/hometown' not found in the predicate catalog
# b'http://dbpedia.org/ontology/restingPlace' not found in the predicate catalog
# b'http://dbpedia.org/ontology/TelevisionShow' not found in the entity catalog
# b'http://dbpedia.org/property/company' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/builder' not found in the predicate catalog
# b'http://dbpedia.org/ontology/sport' not found in the predicate catalog
# b'http://dbpedia.org/ontology/country' not found in the predicate catalog
# b'http://dbpedia.org/ontology/successor' not found in the predicate catalog
# b'http://dbpedia.org/property/placeOfDeath' not found in the predicate catalog
# b'http://dbpedia.org/ontology/location' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Book' not found in the entity catalog
# b'http://dbpedia.org/ontology/author' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/manufacturer' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Scientist' not found in the entity catalog
# b'http://dbpedia.org/property/prizes' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/maintainedBy' not found in the predicate catalog
# b'http://dbpedia.org/ontology/publisher' not found in the predicate catalog
# b'http://dbpedia.org/property/battles' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Band' not found in the entity catalog
# b'http://dbpedia.org/property/label' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/owningCompany' not found in the predicate catalog
# b'http://dbpedia.org/ontology/FictionalCharacter' not found in the entity catalog
# b'http://dbpedia.org/ontology/voice' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/property/tenants' not found in the predicate catalog
# b'http://dbpedia.org/ontology/TelevisionStation' not found in the entity catalog
# b'http://dbpedia.org/property/network' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/deathPlace' not found in the predicate catalog
# b'http://dbpedia.org/ontology/state' not found in the predicate catalog
# b'http://dbpedia.org/ontology/foundedBy' not found in the predicate catalog
# b'http://dbpedia.org/ontology/opponent' not found in the predicate catalog
# b'http://dbpedia.org/property/placeOfBirth' not found in the predicate catalog
# b'http://dbpedia.org/property/awards' not found in the predicate catalog
# b'http://dbpedia.org/ontology/restingPlace' not found in the predicate catalog
# b'http://dbpedia.org/property/mascot' not found in the predicate catalog
# b'http://dbpedia.org/property/houses' not found in the predicate catalog
# b'http://dbpedia.org/property/related' not found in the predicate catalog
# b'http://dbpedia.org/property/state' not found in the predicate catalog
# b'http://dbpedia.org/ontology/board' not found in the predicate catalog
# b'http://dbpedia.org/ontology/operatedBy' not found in the predicate catalog
# b'http://dbpedia.org/ontology/field' not found in the predicate catalog
# b'http://dbpedia.org/ontology/leader' not found in the predicate catalog
# b'http://dbpedia.org/ontology/citizenship' not found in the predicate catalog
# b'http://dbpedia.org/ontology/religion' not found in the predicate catalog
# b'http://dbpedia.org/property/writer' not found in the predicate catalog
# b'http://dbpedia.org/property/president' not found in the predicate catalog
# b'http://dbpedia.org/ontology/religion' not found in the predicate catalog
# b'http://dbpedia.org/ontology/party' not found in the predicate catalog
# b'http://dbpedia.org/property/appointer' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Country' not found in the entity catalog
# b'http://dbpedia.org/ontology/stateOfOrigin' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/author' not found in the predicate catalog
# b'http://dbpedia.org/property/agencyName' not found in the predicate catalog
# b'http://dbpedia.org/ontology/stateOfOrigin' not found in the predicate catalog
# b'http://dbpedia.org/ontology/writer' not found in the predicate catalog
# b'http://dbpedia.org/ontology/award' not found in the predicate catalog
# b'http://dbpedia.org/ontology/builder' not found in the predicate catalog
# b'http://dbpedia.org/property/producer' not found in the predicate catalog
# b'http://dbpedia.org/property/creator' not found in the predicate catalog
# b'http://dbpedia.org/property/awards' not found in the predicate catalog
# b'http://dbpedia.org/ontology/leaderName' not found in the predicate catalog
# b'http://dbpedia.org/ontology/TelevisionShow' not found in the entity catalog
# b'http://dbpedia.org/ontology/network' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/property/combatant' not found in the predicate catalog
# b'http://dbpedia.org/ontology/award' not found in the predicate catalog
# b'http://dbpedia.org/property/purpose' not found in the predicate catalog
# b'http://dbpedia.org/ontology/occupation' not found in the predicate catalog
# b'http://dbpedia.org/ontology/predecessor' not found in the predicate catalog
# b'http://dbpedia.org/ontology/manager' not found in the predicate catalog
# b'http://dbpedia.org/ontology/award' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Company' not found in the entity catalog
# b'http://dbpedia.org/ontology/foundationPlace' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/property/awards' not found in the predicate catalog
# b'http://dbpedia.org/ontology/religion' not found in the predicate catalog
# b'http://dbpedia.org/ontology/firstDriver' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Automobile' not found in the entity catalog
# b'http://dbpedia.org/ontology/predecessor' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Book' not found in the entity catalog
# b'http://dbpedia.org/ontology/author' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/largestCity' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Person' not found in the entity catalog
# b'http://dbpedia.org/ontology/board' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/property/cities' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Newspaper' not found in the entity catalog
# b'http://dbpedia.org/property/owners' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/property/athletics' not found in the predicate catalog
# b'http://dbpedia.org/ontology/deathPlace' not found in the predicate catalog
# b'http://dbpedia.org/property/location' not found in the predicate catalog
# b'http://dbpedia.org/property/agencyName' not found in the predicate catalog
# b'http://dbpedia.org/ontology/broadcastArea' not found in the predicate catalog
# b'http://dbpedia.org/ontology/TelevisionShow' not found in the entity catalog
# b'http://dbpedia.org/property/distributor' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Country' not found in the entity catalog
# b'http://dbpedia.org/property/nationalOrigin' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/manufacturer' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Film' not found in the entity catalog
# b'http://dbpedia.org/property/editing' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Place' not found in the entity catalog
# b'http://dbpedia.org/property/placeOfDeath' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/residence' not found in the predicate catalog
# b'http://dbpedia.org/ontology/series' not found in the predicate catalog
# b'http://dbpedia.org/ontology/owner' not found in the predicate catalog
# b'http://dbpedia.org/ontology/parent' not found in the predicate catalog
# b'http://dbpedia.org/property/birthPlace' not found in the predicate catalog
# b'http://dbpedia.org/property/sourceLocation' not found in the predicate catalog
# b'http://dbpedia.org/property/parent' not found in the predicate catalog
# b'http://dbpedia.org/property/mouthCountry' not found in the predicate catalog
# b'http://dbpedia.org/property/ethnicity' not found in the predicate catalog
# b'http://dbpedia.org/ontology/producer' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Band' not found in the entity catalog
# b'http://dbpedia.org/property/currentMembers' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/leader' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Organisation' not found in the entity catalog
# b'http://dbpedia.org/ontology/maintainedBy' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/almaMater' not found in the predicate catalog
# b'http://dbpedia.org/ontology/majorShrine' not found in the predicate catalog
# b'http://dbpedia.org/ontology/residence' not found in the predicate catalog
# b'http://dbpedia.org/ontology/City' not found in the entity catalog
# b'http://dbpedia.org/property/locationTown' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Place' not found in the entity catalog
# b'http://dbpedia.org/ontology/regionServed' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/product' not found in the predicate catalog
# b'http://dbpedia.org/property/area' not found in the predicate catalog
# b'http://dbpedia.org/ontology/origin' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Band' not found in the entity catalog
# b'http://dbpedia.org/ontology/formerBandMember' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/ontology/routeStart' not found in the predicate catalog
# b'http://dbpedia.org/ontology/city' not found in the predicate catalog
# b'http://dbpedia.org/property/veneratedIn' not found in the predicate catalog
# b'http://dbpedia.org/ontology/regionServed' not found in the predicate catalog
# b'http://dbpedia.org/ontology/commander' not found in the predicate catalog
# b'http://dbpedia.org/ontology/owner' not found in the predicate catalog
# b'http://dbpedia.org/property/school' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Person' not found in the entity catalog
# b'http://dbpedia.org/ontology/firstAscentPerson' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/property/battles' not found in the predicate catalog
# b'http://dbpedia.org/ontology/relation' not found in the predicate catalog
# b'http://dbpedia.org/ontology/formerPartner' not found in the predicate catalog
# b'http://dbpedia.org/property/awards' not found in the predicate catalog
# b'http://dbpedia.org/property/genre' not found in the predicate catalog
# b'http://dbpedia.org/ontology/state' not found in the predicate catalog
# b'http://dbpedia.org/ontology/religion' not found in the predicate catalog
# b'http://dbpedia.org/property/keyPeople' not found in the predicate catalog
# b'http://dbpedia.org/property/address' not found in the predicate catalog
# b'http://dbpedia.org/ontology/tenant' not found in the predicate catalog
# b'http://dbpedia.org/ontology/Film' not found in the entity catalog
# b'http://dbpedia.org/property/music' not found in the predicate catalog
# b'http://www.w3.org/1999/02/22-rdf-syntax-ns#type' not found in the predicate catalog
# b'http://dbpedia.org/property/membership' not found in the predicate catalog
# b'http://dbpedia.org/property/combatant' not found in the predicate catalog
# b'http://dbpedia.org/ontology/formerTeam' not found in the predicate catalog
# 4998 documents annotated with ids
# 0 335 0 2317
# [[], []]
# [[], []]

# %%
# store HDT IDs for questions and answers URIs
loaded = False
limit = None

if not loaded:
    samples = mongo.get_sample(limit=limit)
    count = 0
    for doc in samples:
        # get all correct entity and predicate from the GS annotations
        e_ids = []
        for uri in doc['entity_uris']:
            try:
                e_ids.append(e_index.look_up_by_uri(uri)[0]['_source']['id'])
            except:
                print("%s not found in the entity catalog"%uri)
        doc['entity_ids'] = e_ids

        p_ids = []
        for uri in doc['predicate_uris']:
            try:
                p_ids.append(p_index.look_up_by_uri(uri)[0]['_source']['id'])
            except:
                print("%s not found in the predicate catalog"%uri)
        
        doc['predicate_ids'] = p_ids
        
        if 'answers' in doc:
            a_ids = []
            for uri in doc['answers']:
                try:
                    a_ids.append(e_index.look_up_by_uri(uri)[0]['_source']['id'])
                except:
                    print("%s not found in the entity catalog"%uri)

            doc['answers_ids'] = a_ids
            
        # update doc in MongoDB
        mongo.col.update_one({'_id': doc['_id']}, {"$set": doc}, upsert=True)
        count += 1
        
    print("%d documents annotated with ids"%count)

# show sample annotations
sample = mongo.get_sample(limit=1)[0]
print(sample['entity_ids'])
print(sample['predicate_ids'])
if 'answers' in sample:
    print(sample['answers_ids'])

# %%
# number of documents with 2 hops
print("%d complex questions (with more than one variable)"%mongo.col.find({"2hop": { "$ne": [[], []] }}).count())
print("%d complex questions (with more than one variable)"%mongo.col.find({"train": True, "2hop": { "$ne": [[], []] }}).count())
print("%d complex questions (with more than one variable)"%mongo.col.find({"train": False, "2hop": { "$ne": [[], []] }}).count())

# %%
# number of documents with >1 triple
limit = None
samples = mongo.get_sample(train=True, limit=limit)
counter = 0
for doc in samples:
    n_components = len(doc['predicate_ids']) + len(doc['entity_ids'])
    if n_components > 2:
        counter += 1
print(counter)

# %%
# question lengths distribution
limit = None
from keras.preprocessing.text import text_to_word_sequence
import numpy as np
samples = mongo.get_sample(limit=limit)
n_words_distr = []
for doc in samples:
    words = text_to_word_sequence(doc['question'])
    # add the sample to the dataset 
    n_words_distr.append(len(words))

# show basic stats
min_len = min(n_words_distr)
mean_len = np.mean(n_words_distr)
max_len = max(n_words_distr)
print("Min:%d Avg:%d Max:%d"%(min_len, mean_len, max_len))

# %%
# question number of question URIs distribution (predicate + entity)
from keras.preprocessing.text import text_to_word_sequence
import numpy as np
samples = mongo.get_sample(limit=limit)
n_distr = []
for doc in samples:
    n_distr.append(len(doc['entity_uris']+doc['predicate_uris']))

# show basic stats
min_len = min(n_distr)
mean_len = np.mean(n_distr)
max_len = max(n_distr)
print("Min:%d Avg:%d Max:%d"%(min_len, mean_len, max_len))

# %%
# number of answers per question
import numpy as np

samples = mongo.get_sample(limit=None)
n_distr = []
for doc in samples:
    n_distr.append(len(doc['answers']) if 'answers' in doc else 1)

# show basic stats
min_len = min(n_distr)
mean_len = np.median(n_distr)
max_len = max(n_distr)
print("Min:%d Median:%d Max:%d"%(min_len, mean_len, max_len))
p_distribution = Counter(n_distr)

# %%
# number of unique predicates and distribution 
limit = None

# training set
samples = mongo.get_sample(train=True, limit=limit)
predicates = []
for doc in samples:
    predicates.extend(doc['predicate_uris'])

# test set
samples = mongo.get_sample(train=False, limit=limit)
for doc in samples:
    predicates.extend(doc['predicate_uris'])    


p_distribution = Counter([p for p in predicates if p != 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'])
# most common
print (p_distribution.most_common(30))

predicates = list(set(predicates))
print("%d predicates"%len(predicates))

# %% [markdown]
# * 5 predicates not seen during training
# * most frequent predicate: type ('http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 1568)

# %%
import matplotlib.pyplot as plt

def plot_distribution(counter):
    '''
    Plot the distribution stored in the counter object
    '''
    # prepare data
    import numpy as np
    labels, values = zip(*counter.items())
    indexes = np.arange(len(labels))

    # generate a plot
    import seaborn as sns
    sns.set(color_codes=True)
    sns.distplot(values)
    plt.show()

plot_distribution(p_distribution)

# %%
# write questions into file to generate embeddings
samples = mongo.get_sample(train=True, limit=limit)
os.chdir("/mpqa/KBQA/data/lcquad")
with open('questions.txt', 'w', encoding='utf-8') as fout:
    for doc in samples:
        fout.write(doc['question']+'\n')

# %%
# annotate types separately
loaded = False

verbose = False
limit = None

if not loaded:
    samples = mongo.get_sample(limit=limit)
    count = 0
    for doc in samples:
        # fix URI !
        sparql_query = doc['sparql_query']
        # parse the SPARQL query into spo triples
        tripples = sparql_query[sparql_query.find("{")+1:sparql_query.find("}")].split('. ')

        # collect entities and predicates separately for 2 hops
        classes = []
        cids = []
        for tripple in tripples:
            if tripple:
                entities = []
                s, p, o = tripple.strip().split()
#                     
                p = p[1:-1]
                if p == 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type':
                    if o[0] != '?':
                        uri = o[1:-1]
                        classes.append(uri)
                        try:
                            cids.append(e_index.look_up_by_uri(uri)[0]['_source']['id'])
                        except:
                            print("%s not found in the entity catalog"%uri)
               
        if classes and verbose:
            print(sparql_query)
            print(classes)
            print(cids)
       
        doc['classes'] = classes
        doc['classes_ids'] = cids

        mongo.col.update_one({'_id': doc['_id']}, {"$set": doc}, upsert=True)
        count +=1

    print("%d documents annotated with entities and predicates URIs across hops"%count)

# show sample annotation
sample = mongo.get_by_id("2652").next()
print(sample['sparql_query'])
print(sample['classes'])
print(sample['classes_ids'])

# %% [markdown]
# ## QALD-7

# %%
mongo = Mongo_Connector('kbqa', 'qald_7_train')
data_path = "qald-7-train-multilingual.json"

ENDPOINT = 'https://dbpedia.org/sparql'

# load LC-QUAD dataset
loaded = False

if not loaded:
    import os
    os.chdir("/mpqa/KBQA/data/qald-7")

    import json
    import pprint
    import requests
    with open(data_path, encoding='utf-8') as f:
        dataset = json.load(f)
        for q in dataset['questions']:
            doc = {}
            doc['SerialNumber'] = q['id']
            doc['question'] = q['question'][0]['string']
            doc['sparql_query'] = q['query']['sparql'].replace('\n', ' ')
            response = requests.get(ENDPOINT, params={'query': doc['sparql_query'], 'output': 'json'}).json()
            if 'results' in response:
                results = response['results']['bindings']
                doc['answers'] = [v['value'] for r in results for v in r.values()]
            elif 'boolean' in response:
                doc['bool_answer'] = response['boolean']
            doc['train'] = False
            mongo.col.insert_one(doc)
            
mongo.count_all_docs()
doc = mongo.get_sample(train=False, limit=1)[0]
pprint.pprint(doc)
print(doc['sparql_query'])

# %%
# parse the SPARQL query into spo triples
cursor = mongo.get_sample(limit=1)
with cursor:
    for doc in cursor:
        sparql_query = doc['sparql_query']
        print(sparql_query)
        tripples = sparql_query[sparql_query.find("{")+1:sparql_query.find("}")].split('. ')

        # collect entities and predicates
        for tripple in tripples:
            if tripple:
                entities, predicates = [], []
                clause = tripple.strip().split()
                if clause[0] != 'filter':
                    s, p, o = clause
                    if s[0] != '?':
                        entities.append(s)
                    if o[0] != '?':
                        entities.append(o)
                    predicates.append(p)
                print(entities)
                print(predicates)

# %% [markdown]
# ## QALD-8

# %%
mongo = Mongo_Connector('kbqa', 'qald_7_train')
data_path = "qald-7-train-multilingual.json"

ENDPOINT = 'https://dbpedia.org/sparql'

# load LC-QUAD dataset
loaded = False

if not loaded:
    import os
    os.chdir("/mpqa/KBQA/data/qald-7")

    import json
    import pprint
    import requests
    with open(data_path, encoding='utf-8') as f:
        dataset = json.load(f)
        for q in dataset['questions']:
            doc = {}
            doc['SerialNumber'] = q['id']
            doc['question'] = q['question'][0]['string']
            doc['sparql_query'] = q['query']['sparql'].replace('\n', ' ')
            response = requests.get(ENDPOINT, params={'query': doc['sparql_query'], 'output': 'json'}).json()
            if 'results' in response:
                results = response['results']['bindings']
                doc['answers'] = [v['value'] for r in results for v in r.values()]
            elif 'boolean' in response:
                doc['bool_answer'] = response['boolean']
            doc['train'] = False
            mongo.col.insert_one(doc)
            
mongo.count_all_docs()
doc = mongo.get_sample(train=False, limit=1)[0]
pprint.pprint(doc)
print(doc['sparql_query'])

# parse the SPARQL query into spo triples
cursor = mongo.get_sample(limit=1)
with cursor:
    for doc in cursor:
        sparql_query = doc['sparql_query']
        print(sparql_query)
        tripples = sparql_query[sparql_query.find("{")+1:sparql_query.find("}")].split('. ')

        # collect entities and predicates
        for tripple in tripples:
            if tripple:
                entities, predicates = [], []
                clause = tripple.strip().split()
                if clause[0] != 'filter':
                    s, p, o = clause
                    if s[0] != '?':
                        entities.append(s)
                    if o[0] != '?':
                        entities.append(o)
                    predicates.append(p)
                print(entities)
                print(predicates)
